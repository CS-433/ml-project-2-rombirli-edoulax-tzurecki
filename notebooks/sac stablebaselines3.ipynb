# %% [markdown]
# # SAC
# Using StableBaseline3 SAC implementation

# %% [markdown]
# ## Imports

# %%
import random

from environment import TurbineEnvironment, plot_compare_episodes, simulate_closed_loop_episode, load_test_episode
from parameters import *
import matplotlib.pyplot as plt
from parameters import x_columns
import torch
import shutil

# %%
env = TurbineEnvironment()

# %%
case = 'case 1'
dataset_type = 'res'

# %% [markdown]
# ## Seed

# %%
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False # also needed for deterministic
random.seed(seed)

# %% [markdown]
# ## Load true episode

# %%
true_states, initial_state, true_actions = load_test_episode(case, dataset_type, 0)

# %% [markdown]
# # SAC

# %% [markdown]
# ## Train

# %%
from stable_baselines3 import SAC

tensorboard_dir = output_directory / 'tensorboard'
tensorboard_dir.mkdir(exist_ok=True, parents=True)
tensorboard_dir = tensorboard_dir / "sac_turbine_tensorboard"
# clear tensorboard logs
try:
    shutil.rmtree(tensorboard_dir)
except:
    pass
model_sac = SAC('MlpPolicy', env, tensorboard_log=tensorboard_dir, learning_rate=sac_learning_rate)
model_sac.learn(total_timesteps=sac_total_timesteps, log_interval=10, tb_log_name='sac_turbine', reset_num_timesteps=False)

print(f'tensorboard --logdir {tensorboard_dir.absolute().resolve()}')
# Out:
# tensorboard --logdir C:\Users\Romain\Documents\ML_project2\outputs\tensorboard\sac_turbine_tensorboard

# %% [markdown]
# ## Save

# %%
model_sac.save(output_directory / 'models' / 'stablebaselines_sac')

# %% [markdown]
# ## Test

# %%
states, actions, rewards = simulate_closed_loop_episode(env, model_sac, initial_state)
actions = np.array(actions).reshape(-1)

# %%
plt.plot(np.rad2deg(states[x_columns.index('pitch')]), label='pitch')
plt.plot(list(true_states[x_columns.index('cos_phase')])[:200], label='cos_phase')
plt.legend()
plt.title('Pitch')
plt.show()

# %%
plot_compare_episodes(pred_states=states,
                      pred_actions=actions,
                      true_states=true_states,
                      true_actions=true_actions)
