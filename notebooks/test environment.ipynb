# %% [markdown]
# # Open loop episodes
# This notebook is useful to evaluate the consistency of simulations by the surrogate model by comparing them with true recorded datas.

# %% [markdown]
# ## Imports

# %%
from environment import *

# %%
case = 'case 1'
dataset_type = 'res'

# %%
env = TurbineEnvironment(surrogate_model='surrogate_model_res-full-2023.12.15_23.01.38.zip', dataset_type=dataset_type)

# %% [markdown]
# ## Load true episode

# %%
true_states, initial_state, actions = load_test_episode(case, dataset_type, 1)

# %% [markdown]
# ## Simulate the same episode

# %%
pred_states, pred_rewards = simulate_open_loop_episode(env, actions, initial_state)

# %% [markdown]
# ## Compare

# %%
n=50
plot_compare_episodes(pred_states[:, :n], actions[:n], true_states[:, :n], actions[:n])

# %% [markdown]
# ## Plot the whole episode

# %%
plot_compare_episodes(pred_states, actions, true_states, actions)
